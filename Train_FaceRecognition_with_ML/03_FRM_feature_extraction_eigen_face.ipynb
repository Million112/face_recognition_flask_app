# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import cv2

#eigen face
from sklearn.decomposition import PCA

import pickle

# %%
#Load data

data = pickle.load(open('./data/data_images_300_300.pickle', mode='rb'))

# %%
data.head()
# Out:
#     pixel_0   pixel_1   pixel_2   pixel_3   pixel_4   pixel_5   pixel_6  \
# 0  0.098039  0.101961  0.078431  0.058824  0.054902  0.050980  0.031373
# 1  0.050980  0.062745  0.090196  0.113725  0.105882  0.074510  0.086275
# 3  0.756863  0.752941  0.752941  0.752941  0.752941  0.756863  0.749020
# 4  0.239216  0.235294  0.231373  0.231373  0.231373  0.231373  0.235294
# 5  0.882353  0.882353  0.882353  0.882353  0.882353  0.882353  0.882353
#
#     pixel_7   pixel_8   pixel_9  ...  pixel_89991  pixel_89992  pixel_89993  \
# 0  0.047059  0.043137  0.121569  ...     0.058824     0.054902     0.047059
# 1  0.109804  0.188235  0.207843  ...     0.109804     0.101961     0.094118
# 3  0.756863  0.745098  0.749020  ...     0.737255     0.733333     0.733333
# 4  0.235294  0.231373  0.223529  ...     0.215686     0.215686     0.215686
# 5  0.882353  0.882353  0.882353  ...     0.349020     0.337255     0.349020
#
#    pixel_89994  pixel_89995  pixel_89996  pixel_89997  pixel_89998  \
# 0     0.098039     0.039216     0.050980     0.062745     0.101961
# 1     0.082353     0.078431     0.082353     0.094118     0.098039
# 3     0.733333     0.737255     0.741176     0.741176     0.745098
# 4     0.215686     0.215686     0.215686     0.215686     0.215686
# 5     0.349020     0.294118     0.388235     0.490196     0.423529
#
#    pixel_89999  gender
# 0     0.074510  female
# 1     0.098039  female
# 3     0.741176  female
# 4     0.215686  female
# 5     0.482353  female
#
# [5 rows x 90001 columns]

# %%
#mean face
X = data.drop('gender', axis=1).values

# %%
X
# Out:
# array([[0.09803922, 0.10196078, 0.07843137, ..., 0.0627451 , 0.10196078,
#         0.0745098 ],
#        [0.05098039, 0.0627451 , 0.09019608, ..., 0.09411765, 0.09803922,
#         0.09803922],
#        [0.75686275, 0.75294118, 0.75294118, ..., 0.74117647, 0.74509804,
#         0.74117647],
#        ...,
#        [0.8       , 0.80392157, 0.80392157, ..., 0.99215686, 0.99215686,
#         0.99215686],
#        [0.78039216, 0.78431373, 0.70980392, ..., 0.8627451 , 0.8627451 ,
#         0.8627451 ],
#        [0.33333333, 0.33333333, 0.32941176, ..., 0.65882353, 0.71372549,
#         0.78823529]], shape=(90, 90000))

# %%
mean_face = X.mean(axis=0)
mean_face.shape
# Out:
# (90000,)

# %%
#visualize mean face
plt.imshow(mean_face.reshape((300,300)), cmap='gray')
plt.axis('off')
plt.show()

# %%
#subtract data with mean face

# %%
X_t = X - mean_face #transform data

# %%
#apply X_t data to PCA
pca = PCA(n_components=None, whiten=True,svd_solver='auto')
pca.fit(X_t)
# Out:
# PCA(whiten=True)

# %%
exp_var_df = pd.DataFrame()
exp_var_df['explained_var'] = pca.explained_variance_ratio_
exp_var_df['cum_explained_var'] = exp_var_df['explained_var'].cumsum()
exp_var_df['principal_components'] = np.arange(1,len(exp_var_df)+1)

exp_var_df.head()
# Out:
#    explained_var  cum_explained_var  principal_components
# 0       0.268864           0.268864                     1
# 1       0.140969           0.409833                     2
# 2       0.124351           0.534184                     3
# 3       0.061755           0.595940                     4
# 4       0.034091           0.630031                     5

# %%
exp_var_df.set_index('principal_components', inplace=True)

# %%
fig, ax = plt.subplots(nrows=2, figsize=(15,12))

exp_var_df['explained_var'].head(100).plot(kind='line', marker='o', ax=ax[0])
exp_var_df['cum_explained_var'].head(100).plot(kind='line', marker='o', ax=ax[1])
# Out:
# <Axes: xlabel='principal_components'>

# %%
pca_50 = PCA(n_components=50, whiten=True,svd_solver='auto')
pca_data = pca_50.fit_transform(X_t)

# %%
pca_data.shape
# Out:
# (90, 50)

# %%
#sacing data and model
y = data['gender'].values
np.savez('./data/data_pca_50_target', pca_data, y)

# %%
#saving the model
pca_dict = {'pca':pca_50, 'mean_face':mean_face}

# %%
pickle.dump(pca_dict, open('model/pca_dict.pickle','wb'))

# %%
pca_data_inv = pca_50.inverse_transform(pca_data)

# %%
pca_data_inv.shape
# Out:
# (90, 90000)

# %%
eig_img = pca_data_inv[0,:].reshape((300, 300))
eig_img.shape
# Out:
# (300, 300)

# %%
plt.imshow(eig_img, cmap='gray')
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(299.5), np.float64(299.5), np.float64(-0.5))

# %%
np.random.seed(1001)
pics = np.random.randint(0, 90, 40)
plt.figure(figsize = (15, 8))
for i, pic in enumerate(pics):
    plt.subplot(4,10,i+1)
    img = X[pic:pic+1].reshape(300, 300)
    plt.imshow(img, cmap='gray')
    plt.title('{}'.format(y[pic]))
    plt.xticks([])
    plt.yticks([])
plt.show()

print("="*20+'Eigen Imgaes'+"="*20)
plt.figure(figsize=(15,8))
for i, pic in enumerate(pics):
    plt.subplot(4,10,i+1)
    img = pca_data_inv[pic:pic+1].reshape(300, 300)
    plt.imshow(img, cmap='gray')
    plt.title('{}'.format(y[pic]))
    plt.xticks([])
    plt.yticks([])

plt.show()
# Out:
# ====================Eigen Imgaes====================
